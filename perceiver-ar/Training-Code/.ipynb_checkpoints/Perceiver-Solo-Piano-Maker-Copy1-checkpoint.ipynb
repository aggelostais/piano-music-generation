# %% [markdown]
# ***
#
# # Perceiver Solo Piano Maker (Version 1.0)
#
# https://github.com/asigalov61/tegridy-tools
#
# https://github.com/lucidrains/perceiver-ar-pytorch
#
# ## Project Los Angeles
# ## Tegridy Code 2022
#
# ***

# %% [markdown]
# # GPU check

# %%
# !nvidia-smi
# !export CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# # Install dependencies and import modules

# %%
# !cd '/home/astais/Perceiver-Music-Transformer/Training-Code'
# !git clone https://github.com/asigalov61/tegridy-tools
# Out:
# /bin/bash: /home/astais/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !pip install einops
# !pip install torch-summary
# !pip install sklearn
# !pip install matplotlib

# %%
# Load modules and make data dir

print('Loading modules...')

import pickle,os,random,secrets,datetime
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)

import torch
import torch.optim as optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary
from sklearn import metrics

# %cd /home/astais/Perceiver-Music-Transformer/Training-Code/tegridy-tools/tegridy-tools/

import TMIDIX

# %cd /home/astais/Perceiver-Music-Transformer/Training-Code/tegridy-tools/tegridy-tools/Perceiver-AR/

from perceiver_ar_pytorch import PerceiverAR
from autoregressive_wrapper import AutoregressiveWrapper

# %cd /home/astais/Perceiver-Music-Transformer/Training-Code/

print('Done.')
# Out:
# Loading modules...
# /home/astais/Perceiver-Music-Transformer/Training-Code/tegridy-tools/tegridy-tools
# /home/astais/Perceiver-Music-Transformer/Training-Code/tegridy-tools/tegridy-tools/Perceiver-AR
# /home/astais/Perceiver-Music-Transformer/Training-Code
# Done.

# %% [markdown]
# ## Set Training Dataset and Directory Paths

# %%
dataset_name='Los-Angeles-MIDI-Dataset'
preprocess_addr = "/data/ironman/data1/users/astais/Unprocessed-Datasets/"+dataset_name
dataset_addr='/data/ironman/data1/users/astais/Processed-Datasets/perceiver-ar/perceiver-ar_'+dataset_name
current_time = datetime.datetime.now().strftime('%Y%m%d')
base_save_dir='/data/ironman/data1/users/astais/Saved-Models/perceiver-ar/'
train_out_dir='/data/ironman/data1/users/astais/Training-Ouputs/perceiver-ar/'+'perceiver-ar_'+dataset_name+'_'+current_time+'/'

for addr in [dataset_addr,train_out_dir]:
    if not os.path.exists(addr):
        os.makedirs(addr)

# %% [markdown]
# # (Preprocess Training Data)

# %%
#@title Process MIDIs with TMIDIX MIDI Processor

#@title Process MIDIs

sorted_or_random_file_loading_order = False # Sorted order is NOT usually recommended
dataset_ratio = 1 # Change this if you need more data


print('TMIDIX MIDI Processor')
print('Starting up...')
###########

files_count = 0

gfiles = []

train_data1 = []

###########

print('Loading MIDI files...')
print('This may take a while on a large dataset in particular.')

# os.chdir(dataset_addr)
filez = list()
for (dirpath, dirnames, filenames) in os.walk(preprocess_addr):
    filez += [os.path.join(dirpath, file) for file in filenames]
print('=' * 70)

if filez == []:
    print('Could not find any MIDI files. Please check Dataset dir...')
    print('=' * 70)

if sorted_or_random_file_loading_order:
    print('Sorting files...')
    filez.sort()
    print('Done!')
    print('=' * 70)
else:
    print('Randomizing file list...')
    random.shuffle(filez)


print('Processing MIDI files. Please wait...')
for f in tqdm(filez[:int(len(filez) * dataset_ratio)]):
    try:
        fn = os.path.basename(f)
        fn1 = fn.split('.')[0]

        #print('Loading MIDI file...')
        score = TMIDIX.midi2ms_score(open(f, 'rb').read())

        events_matrix = []

        itrack = 1

        while itrack < len(score):
            for event in score[itrack]:         
                if event[0] == 'note' and event[3] != 9:
                    events_matrix.append(event)
            itrack += 1
        
        if len(events_matrix) > 0:

          # Sorting...
          events_matrix.sort(key=lambda x: x[4], reverse=True)
          events_matrix.sort(key=lambda x: x[1])

          # recalculating timings
          for e in events_matrix:
              e[1] = int(e[1] / 10)
              e[2] = int(e[2] / 20)
          
          # final processing...

          train_data1.extend([126+0, 126+128, 0+256, 0+384]) # Intro/Zero seq

          pe = events_matrix[0]
          for e in events_matrix:

              time = max(0, min(126, e[1]-pe[1]))
              dur = max(1, min(126, e[2]))
              ptc = max(1, min(126, e[4]))
              vel = max(1, min(126, e[5]))

              train_data1.extend([time+0, dur+128, ptc+256, vel+384])

              pe = e

          files_count += 1
        
    except KeyboardInterrupt:
        print('Quitting...')
        break  

    except:
        print('Bad MIDI:', f)
        continue

print('=' * 70)
TMIDIX.Tegridy_Any_Pickle_File_Writer(train_data1, dataset_addr+'/perceiver-ar_'+dataset_name) 
print('Done!')   
print('=' * 70)
# Out:
# TMIDIX MIDI Processor
# Starting up...
# Loading MIDI files...
# This may take a while on a large dataset in particular.
# ======================================================================
# Randomizing file list...
# Processing MIDI files. Please wait...
#   0%|                                                                                                                              | 189/939961 [03:48<113:27:58,  2.30it/s]set_sequence_number: length must be 2, not 0
#   0%|                                                                                                                               | 238/939961 [03:57<47:33:30,  5.49it/s]midi2opus: track #2 length 710937737 is too large
#   0%|                                                                                                                               | 298/939961 [04:08<69:11:59,  3.77it/s]midi2opus: track #12 length 2203346020 is too large
#   0%|                                                                                                                               | 365/939961 [07:36<42:06:04,  6.20it/s]midi2opus: midi starts with b'\x06\x1c\x08\x1d' instead of 'MThd'
#   0%|                                                                                                                               | 435/939961 [07:44<38:52:51,  6.71it/s]midi2opus: track #2 length 828667697 is too large
#   0%|                                                                                                                               | 453/939961 [07:45<15:06:44, 17.27it/s]midi2opus: track #14 length 2770442 is too large
#   0%|                                                                                                                               | 469/939961 [07:48<46:46:39,  5.58it/s]midi2opus: track #17 length 431427 is too large
#   0%|                                                                                                                               | 556/939961 [07:58<21:01:34, 12.41it/s]midi2opus: track #2 length 4143380214 is too large
#   0%|                                                                                                                               | 692/939961 [08:17<49:35:50,  5.26it/s]midi2opus: track #7 length 4177066232 is too large
#   0%|                                                                                                                               | 817/939961 [08:30<26:46:15,  9.74it/s]midi2opus: track #3 length 11542 is too large
#   0%|                                                                                                                               | 899/939961 [08:41<22:00:45, 11.85it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   0%|                                                                                                                               | 901/939961 [08:42<26:19:55,  9.91it/s]midi2opus: track #2 length 1174416226 is too large
#   0%|▏                                                                                                                             | 1015/939961 [08:56<46:14:56,  5.64it/s]midi2opus: track #16 length 1262654009 is too large
#   0%|▏                                                                                                                             | 1213/939961 [09:19<18:03:20, 14.44it/s]midi2opus: track #2 length 437918234 is too large
#   0%|▏                                                                                                                             | 1243/939961 [09:23<54:07:28,  4.82it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   0%|▏                                                                                                                             | 1251/939961 [09:24<34:06:40,  7.64it/s]midi2opus: track #2 length 1330597711 is too large
#   0%|▏                                                                                                                             | 1359/939961 [09:39<25:11:51, 10.35it/s]midi2opus: track #14 length 437918234 is too large
#   0%|▏                                                                                                                             | 1425/939961 [09:49<35:04:24,  7.43it/s]midi2opus: track #9 length 5264 is too large
#   0%|▏                                                                                                                             | 1495/939961 [09:59<25:25:59, 10.25it/s]midi2opus: track #18 length 2303756106 is too large
#   0%|▏                                                                                                                             | 1499/939961 [09:59<33:38:24,  7.75it/s]midi2opus: track #7 length 11856 is too large
#   0%|▏                                                                                                                             | 1581/939961 [10:09<24:52:17, 10.48it/s]midi2opus: track #13 length 2301247564 is too large
#   0%|▏                                                                                                                             | 1728/939961 [10:31<33:06:38,  7.87it/s]midi2opus: track #2 length 1346372224 is too large
#   0%|▏                                                                                                                             | 1757/939961 [10:35<37:55:41,  6.87it/s]midi2opus: track #2 length 544499064 is too large
#   0%|▏                                                                                                                             | 1816/939961 [10:44<37:28:18,  6.95it/s]set_sequence_number: length must be 2, not 0
#   0%|▎                                                                                                                             | 1955/939961 [11:04<33:27:35,  7.79it/s]midi2opus: track #12 length 2151235597 is too large
#   0%|▎                                                                                                                             | 1981/939961 [11:06<31:19:41,  8.32it/s]midi2opus: track #15 length 125192380 is too large
#   0%|▎                                                                                                                             | 2094/939961 [11:23<42:08:57,  6.18it/s]midi2opus: track #18 length 1382442137 is too large
#   0%|▎                                                                                                                             | 2131/939961 [11:27<34:43:24,  7.50it/s]midi2opus: midi starts with b'<htm' instead of 'MThd'
#   0%|▎                                                                                                                             | 2175/939961 [11:31<26:52:46,  9.69it/s]midi2opus: track #6 length 1497563136 is too large
#   0%|▎                                                                                                                             | 2247/939961 [11:41<39:42:00,  6.56it/s]midi2opus: track #1 length 72150 is too large
# midi2opus: track #6 length 4545 is too large
#   0%|▎                                                                                                                             | 2314/939961 [11:51<55:28:03,  4.70it/s]midi2opus: track #2 length 2436956171 is too large
#   0%|▎                                                                                                                             | 2319/939961 [11:52<42:08:29,  6.18it/s]midi2opus: track #15 length 1129466192 is too large
#   0%|▎                                                                                                                             | 2325/939961 [11:53<32:08:15,  8.10it/s]midi2opus: track #2 length 2569689345 is too large
#   0%|▎                                                                                                                             | 2357/939961 [11:59<49:41:17,  5.24it/s]midi2opus: midi starts with b'<br ' instead of 'MThd'
#   0%|▎                                                                                                                             | 2431/939961 [12:11<42:40:19,  6.10it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   0%|▎                                                                                                                             | 2496/939961 [12:20<57:41:50,  4.51it/s]midi2opus: track #13 length 437918234 is too large
#   0%|▎                                                                                                                             | 2627/939961 [12:41<33:56:20,  7.67it/s]midi2opus: track #4 length 1229212044 is too large
#   0%|▎                                                                                                                             | 2631/939961 [12:42<52:21:28,  4.97it/s]midi2opus: track #9 length 17421 is too large
#   0%|▎                                                                                                                             | 2691/939961 [12:51<26:53:52,  9.68it/s]midi2opus: track #9 length 7124 is too large
#   0%|▎                                                                                                                             | 2713/939961 [12:53<23:25:06, 11.12it/s]midi2opus: track #14 length 1633837669 is too large
#   0%|▎                                                                                                                             | 2789/939961 [13:07<56:05:55,  4.64it/s]midi2opus: track #2 length 759172754 is too large
#   0%|▍                                                                                                                             | 2820/939961 [13:11<28:19:43,  9.19it/s]midi2opus: track #2 length 2569830144 is too large
#   0%|▍                                                                                                                             | 2834/939961 [13:13<49:45:25,  5.23it/s]midi2opus: track #12 length 32832 is too large
#   0%|▍                                                                                                                             | 2850/939961 [13:15<19:19:19, 13.47it/s]midi2opus: track #21 length 52625408 is too large
#   0%|▍                                                                                                                             | 2874/939961 [13:18<44:26:06,  5.86it/s]set_sequence_number: length must be 2, not 5
#   0%|▍                                                                                                                             | 2888/939961 [13:20<36:41:02,  7.10it/s]midi2opus: midi starts with b'ENIG' instead of 'MThd'
#   0%|▍                                                                                                                             | 3035/939961 [13:43<50:49:52,  5.12it/s]midi2opus: midi starts with b'vti_' instead of 'MThd'
#   0%|▍                                                                                                                             | 3077/939961 [13:49<42:52:36,  6.07it/s]midi2opus: track #9 length 2325545215 is too large
#   0%|▍                                                                                                                             | 3089/939961 [13:51<37:41:10,  6.91it/s]midi2opus: track #2 length 2131794203 is too large
#   0%|▍                                                                                                                             | 3124/939961 [13:58<44:10:07,  5.89it/s]midi2opus: track #2 length 75952 is too large
#   0%|▍                                                                                                                             | 3190/939961 [14:12<34:05:25,  7.63it/s]midi2opus: midi starts with b'<!DO' instead of 'MThd'
#   0%|▍                                                                                                                             | 3337/939961 [14:43<53:10:48,  4.89it/s]midi2opus: track #2 length 8664896 is too large
#   0%|▍                                                                                                                             | 3347/939961 [14:46<65:26:18,  3.98it/s]midi2opus: track #12 length 1677738340 is too large
#   0%|▍                                                                                                                             | 3469/939961 [15:13<34:55:01,  7.45it/s]midi2opus: track #50 length 1129466192 is too large
#   0%|▍                                                                                                                             | 3476/939961 [15:15<84:17:43,  3.09it/s]midi2opus: track #3 length 16040 is too large
#   0%|▍                                                                                                                             | 3500/939961 [15:21<45:30:41,  5.72it/s]midi2opus: track #2 length 10237744 is too large
#   0%|▍                                                                                                                             | 3570/939961 [15:37<55:40:23,  4.67it/s]midi2opus: track #2 length 1348560741 is too large
#   0%|▍                                                                                                                             | 3662/939961 [15:57<61:04:55,  4.26it/s]midi2opus: track #8 length 2139177091 is too large
#   0%|▌                                                                                                                             | 3846/939961 [16:36<47:24:14,  5.49it/s]midi2opus: track #2 length 67264520 is too large
#   0%|▌                                                                                                                             | 3850/939961 [16:37<74:19:47,  3.50it/s]midi2opus: track #4 length 1998 is too large
#   0%|▌                                                                                                                             | 3931/939961 [16:53<30:49:41,  8.43it/s]midi2opus: track #32 length 1078107196 is too large
#   0%|▌                                                                                                                             | 4120/939961 [17:37<37:47:10,  6.88it/s]midi2opus: track #14 length 761548544 is too large
#   0%|▌                                                                                                                             | 4230/939961 [18:03<58:17:22,  4.46it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   0%|▌                                                                                                                             | 4250/939961 [18:08<86:44:17,  3.00it/s]midi2opus: track #2 length 591398324 is too large
#   0%|▌                                                                                                                             | 4359/939961 [18:37<57:08:56,  4.55it/s]midi2opus: track #19 length 1633837669 is too large
#   0%|▌                                                                                                                             | 4403/939961 [18:47<92:31:12,  2.81it/s]midi2opus: track #18 length 26693492 is too large
#   0%|▌                                                                                                                             | 4428/939961 [18:51<26:39:46,  9.75it/s]midi2opus: track #8 length 4268 is too large
#   0%|▌                                                                                                                            | 4598/939961 [19:41<141:53:19,  1.83it/s]midi2opus: track #20 length 25773120 is too large
#   1%|▋                                                                                                                             | 4722/939961 [20:11<74:52:21,  3.47it/s]midi2opus: track #15 length 144321393 is too large
#   1%|▋                                                                                                                            | 4829/939961 [22:01<471:28:45,  1.82s/it]midi2opus: track #14 length 5678 is too large
#   1%|▋                                                                                                                            | 4884/939961 [23:33<430:26:10,  1.66s/it]midi2opus: track #2 length 1059 is too large
#   1%|▋                                                                                                                            | 4921/939961 [24:38<281:56:58,  1.09s/it]midi2opus: track #11 length 855639352 is too large
#   1%|▋                                                                                                                             | 5077/939961 [25:23<61:56:14,  4.19it/s]midi2opus: track #2 length 894763417 is too large
#   1%|▋                                                                                                                             | 5159/939961 [25:48<31:58:01,  8.12it/s]midi2opus: track #2 length 1633837669 is too large
#   1%|▋                                                                                                                             | 5181/939961 [25:54<42:53:13,  6.05it/s]midi2opus: track #3 length 184616629 is too large
#   1%|▋                                                                                                                             | 5197/939961 [25:59<89:17:22,  2.91it/s]midi2opus: track #2 length 846072464 is too large
#   1%|▋                                                                                                                             | 5210/939961 [26:03<66:04:48,  3.93it/s]midi2opus: midi starts with b'PK\x03\x04' instead of 'MThd'
#   1%|▋                                                                                                                             | 5249/939961 [26:12<65:09:57,  3.98it/s]midi2opus: track #15 length 1818850152 is too large
#   1%|▋                                                                                                                             | 5275/939961 [26:20<49:51:58,  5.21it/s]midi2opus: track #17 length 1795162112 is too large
#   1%|▋                                                                                                                             | 5278/939961 [26:21<78:03:34,  3.33it/s]midi2opus: track #14 length 662643642 is too large
#   1%|▋                                                                                                                             | 5329/939961 [26:36<98:51:45,  2.63it/s]midi2opus: track #2 length 828667697 is too large
#   1%|▋                                                                                                                             | 5337/939961 [26:39<71:36:41,  3.63it/s]midi2opus: midi starts with b'<HEA' instead of 'MThd'
#   1%|▋                                                                                                                             | 5378/939961 [26:52<98:18:04,  2.64it/s]midi2opus: track #5 length 437918234 is too large
#   1%|▋                                                                                                                            | 5565/939961 [27:54<136:48:08,  1.90it/s]midi2opus: track #11 length 861798553 is too large
#   1%|▋                                                                                                                            | 5622/939961 [28:49<405:01:56,  1.56s/it]midi2opus: track #2 length 706944392 is too large
#   1%|▊                                                                                                                            | 5666/939961 [30:13<286:33:33,  1.10s/it]midi2opus: track #16 length 7099 is too large
#   1%|▊                                                                                                                            | 5673/939961 [30:27<486:57:02,  1.88s/it]midi2opus: midi starts with b'\x00\x05Ta' instead of 'MThd'
#   1%|▊                                                                                                                            | 5677/939961 [30:34<465:47:55,  1.79s/it]midi2opus: track #21 length 1916411989 is too large
#   1%|▊                                                                                                                             | 5790/939961 [32:29<99:06:08,  2.62it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   1%|▊                                                                                                                             | 5815/939961 [32:33<65:41:39,  3.95it/s]midi2opus: track #13 length 10240 is too large
#   1%|▊                                                                                                                             | 5943/939961 [32:59<27:09:10,  9.56it/s]midi2opus: track #11 length 1477215313 is too large
#   1%|▊                                                                                                                            | 6028/939961 [33:18<101:36:27,  2.55it/s]midi2opus: track #10 length 1869414655 is too large
#   1%|▊                                                                                                                             | 6140/939961 [33:39<50:20:00,  5.15it/s]midi2opus: track #7 length 32 is too large
#   1%|▊                                                                                                                             | 6177/939961 [33:48<94:18:17,  2.75it/s]midi2opus: track #6 length 11550847 is too large
#   1%|▊                                                                                                                             | 6300/939961 [34:12<47:23:55,  5.47it/s]midi2opus: track #9 length 4445 is too large
#   1%|▊                                                                                                                             | 6428/939961 [34:41<65:26:37,  3.96it/s]midi2opus: midi starts with b'MSCF' instead of 'MThd'
#   1%|▊                                                                                                                             | 6492/939961 [34:57<82:07:57,  3.16it/s]midi2opus: track #8 length 11929376 is too large
#   1%|▊                                                                                                                             | 6504/939961 [34:58<26:45:22,  9.69it/s]Running status not set; Aborting track.
# midi2opus: track #2 length 1376511 is too large
#   1%|▊                                                                                                                             | 6510/939961 [35:00<52:42:42,  4.92it/s]midi2opus: track #2 length 1012203667 is too large
#   1%|▊                                                                                                                             | 6512/939961 [35:00<45:51:01,  5.66it/s]time_signature event, but length=2
#   1%|▊                                                                                                                             | 6516/939961 [35:01<49:17:33,  5.26it/s]midi2opus: track #2 length 14965549 is too large
#   1%|▉                                                                                                                            | 6652/939961 [36:06<575:49:41,  2.22s/it]midi2opus: track #2 length 2387017318 is too large
#   1%|▉                                                                                                                            | 6706/939961 [38:06<449:44:49,  1.73s/it]midi2opus: track #14 length 10749 is too large
#   1%|▉                                                                                                                            | 6713/939961 [38:24<566:31:00,  2.19s/it]midi2opus: track #12 length 1362527613 is too large
#   1%|▉                                                                                                                            | 6728/939961 [38:52<470:13:31,  1.81s/it]midi2opus: track #1 length 159974 is too large
#   1%|▉                                                                                                                            | 6755/939961 [39:42<686:27:31,  2.65s/it]midi2opus: track #2 length 25766464 is too large
#   1%|▉                                                                                                                             | 6779/939961 [40:06<89:03:22,  2.91it/s]midi2opus: track #2 length 1350500505 is too large
#   1%|▉                                                                                                                             | 6811/939961 [40:13<50:52:31,  5.09it/s]Running status not set; Aborting track.
#   1%|▉                                                                                                                             | 6856/939961 [40:21<27:58:52,  9.26it/s]midi2opus: track #10 length 62785381 is too large
#   1%|▉                                                                                                                             | 6863/939961 [40:22<45:44:47,  5.67it/s]midi2opus: track #26 length 102891520 is too large
#   1%|▉                                                                                                                             | 6961/939961 [40:40<37:39:39,  6.88it/s]midi2opus: midi starts with b'vti_' instead of 'MThd'
#   1%|▉                                                                                                                             | 7003/939961 [40:48<49:00:52,  5.29it/s]midi2opus: track #2 length 2420143872 is too large
# midi2opus: track #9 length 10597 is too large
#   1%|▉                                                                                                                         | 7122/939961 [1:05:41<6532:24:26, 25.21s/it]midi2opus: track #2 length 1768977470 is too large
#   1%|▉                                                                                                                           | 7194/939961 [1:06:00<90:55:32,  2.85it/s]midi2opus: midi starts with b'MTM\x10' instead of 'MThd'
#   1%|▉                                                                                                                           | 7317/939961 [1:06:34<50:20:06,  5.15it/s]midi2opus: track #16 length 21659421 is too large
#   1%|▉                                                                                                                           | 7321/939961 [1:06:35<67:52:18,  3.82it/s]midi2opus: track #10 length 1313098831 is too large
#   1%|▉                                                                                                                           | 7339/939961 [1:06:38<30:31:11,  8.49it/s]midi2opus: track #20 length 3212509313 is too large
#   1%|█                                                                                                                           | 7597/939961 [1:07:53<75:49:07,  3.42it/s]midi2opus: track #15 length 1936024608 is too large
#   1%|█                                                                                                                           | 7617/939961 [1:07:58<86:45:25,  2.99it/s]midi2opus: track #54 length 437918234 is too large
#   1%|█                                                                                                                           | 7640/939961 [1:08:06<67:04:15,  3.86it/s]midi2opus: track #2 length 2003725423 is too large
#   1%|█                                                                                                                           | 7846/939961 [1:09:03<77:09:59,  3.36it/s]midi2opus: track #2 length 1627560246 is too large
#   1%|█                                                                                                                           | 7920/939961 [1:09:18<65:53:35,  3.93it/s]midi2opus: track #9 length 1207959880 is too large
#   1%|█                                                                                                                          | 7953/939961 [1:09:29<119:41:41,  2.16it/s]midi2opus: track #1 length 65156 is too large
#   1%|█                                                                                                                           | 8034/939961 [1:09:49<60:30:41,  4.28it/s]midi2opus: track #25 length 2205947904 is too large
#   1%|█                                                                                                                           | 8065/939961 [1:09:56<49:56:53,  5.18it/s]midi2opus: track #12 length 1879192438 is too large
#   1%|█                                                                                                                           | 8110/939961 [1:10:08<30:06:39,  8.60it/s]midi2opus: track #14 length 11929445 is too large
#   1%|█                                                                                                                           | 8122/939961 [1:10:13<79:35:14,  3.25it/s]midi2opus: track #25 length 540824389 is too large
#   1%|█                                                                                                                           | 8188/939961 [1:10:45<84:20:55,  3.07it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   1%|█                                                                                                                           | 8198/939961 [1:10:46<64:13:03,  4.03it/s]midi2opus: track #10 length 1107306302 is too large
#   1%|█                                                                                                                           | 8209/939961 [1:10:50<96:50:57,  2.67it/s]midi2opus: track #9 length 1348148814 is too large
#   1%|█                                                                                                                          | 8239/939961 [1:11:00<103:57:29,  2.49it/s]_unshift_ber_int: no integer found
#   1%|█                                                                                                                           | 8274/939961 [1:11:08<45:33:52,  5.68it/s]midi2opus: track #6 length 12990 is too large
#   1%|█                                                                                                                           | 8341/939961 [1:11:24<69:35:15,  3.72it/s]midi2opus: track #19 length 2435397720 is too large
#   1%|█                                                                                                                           | 8348/939961 [1:11:25<68:41:48,  3.77it/s]midi2opus: track #6 length 2621440 is too large
#   1%|█                                                                                                                           | 8487/939961 [1:12:12<90:18:33,  2.87it/s]midi2opus: track #5 length 437918234 is too large
#   1%|█                                                                                                                          | 8565/939961 [1:12:34<115:24:47,  2.24it/s]set_sequence_number: length must be 2, not 0
#   1%|█▏                                                                                                                         | 8622/939961 [1:12:51<135:03:43,  1.92it/s]midi2opus: midi starts with b'\x00\x14Ra' instead of 'MThd'
#   1%|█▏                                                                                                                          | 8744/939961 [1:13:29<84:31:30,  3.06it/s]midi2opus: track #13 length 1900799 is too large
#   1%|█▏                                                                                                                         | 8831/939961 [1:14:00<127:28:09,  2.03it/s]midi2opus: midi starts with b'days' instead of 'MThd'
#   1%|█▏                                                                                                                         | 8895/939961 [1:14:23<121:20:11,  2.13it/s]midi2opus: track #6 length 2963 is too large
#   1%|█▏                                                                                                                          | 8908/939961 [1:14:26<52:31:02,  4.92it/s]midi2opus: track #12 length 437918234 is too large
#   1%|█▏                                                                                                                          | 8980/939961 [1:14:50<55:43:11,  4.64it/s]_unshift_ber_int: no integer found
# midi2opus: track #2 length 1795162158 is too large
#   1%|█▏                                                                                                                          | 9102/939961 [1:15:21<75:29:05,  3.43it/s]midi2opus: midi starts with b'vti_' instead of 'MThd'
#   1%|█▏                                                                                                                          | 9122/939961 [1:15:25<66:21:58,  3.90it/s]midi2opus: track #19 length 1397764743 is too large
#   1%|█▏                                                                                                                         | 9269/939961 [1:16:16<231:31:44,  1.12it/s]midi2opus: track #10 length 1935897193 is too large
#   1%|█▏                                                                                                                          | 9360/939961 [1:16:46<84:52:59,  3.05it/s]midi2opus: track #9 length 8396 is too large
#   1%|█▏                                                                                                                          | 9401/939961 [1:17:02<69:09:29,  3.74it/s]midi2opus: track #9 length 3682 is too large
#   1%|█▎                                                                                                                          | 9751/939961 [1:18:46<52:58:01,  4.88it/s]midi2opus: midi starts with b'Rar!' instead of 'MThd'
#   1%|█▎                                                                                                                         | 9862/939961 [1:19:16<102:21:32,  2.52it/s]midi2opus: track #20 length 213256056 is too large
#   1%|█▎                                                                                                                         | 9922/939961 [1:19:55<409:48:23,  1.59s/it]midi2opus: track #18 length 760956034 is too large
#   1%|█▎                                                                                                                        | 10003/939961 [1:21:38<115:04:01,  2.24it/s]midi2opus: track #2 length 2569289472 is too large
#   1%|█▎                                                                                                                         | 10008/939961 [1:21:39<78:09:59,  3.30it/s]midi2opus: track #18 length 739946 is too large
#   1%|█▎                                                                                                                         | 10051/939961 [1:21:50<59:04:53,  4.37it/s]midi2opus: track #9 length 16735 is too large
#   1%|█▎                                                                                                                         | 10060/939961 [1:21:53<70:25:35,  3.67it/s]midi2opus: track #2 length 710284681 is too large
#   1%|█▎                                                                                                                         | 10121/939961 [1:22:15<61:02:13,  4.23it/s]midi2opus: midi starts with b'#===' instead of 'MThd'
#   1%|█▎                                                                                                                        | 10159/939961 [1:22:29<134:39:34,  1.92it/s]midi2opus: track #2 length 8726592 is too large
#   1%|█▎                                                                                                                        | 10166/939961 [1:22:34<188:18:04,  1.37it/s]midi2opus: track #17 length 1049320003 is too large
#   1%|█▎                                                                                                                        | 10270/939961 [1:23:14<121:11:25,  2.13it/s]midi2opus: track #25 length 67174191 is too large
#   1%|█▎                                                                                                                         | 10325/939961 [1:23:32<91:34:21,  2.82it/s]midi2opus: midi starts with b'<htm' instead of 'MThd'
#   1%|█▎                                                                                                                         | 10340/939961 [1:23:36<70:55:45,  3.64it/s]midi2opus: track #14 length 15996 is too large
#   1%|█▎                                                                                                                        | 10359/939961 [1:23:44<131:30:27,  1.96it/s]midi2opus: track #2 length 1330597711 is too large
#   1%|█▎                                                                                                                         | 10383/939961 [1:23:48<25:08:23, 10.27it/s]Running status not set; Aborting track.
# midi2opus: track #17 length 1795162126 is too large
#   1%|█▎                                                                                                                         | 10394/939961 [1:23:54<99:37:34,  2.59it/s]midi2opus: track #10 length 603980185 is too large
#   1%|█▍                                                                                                                        | 10608/939961 [1:25:47<432:33:01,  1.68s/it]midi2opus: track #21 length 1317105804 is too large
#   1%|█▍                                                                                                                        | 10626/939961 [1:26:18<428:38:46,  1.66s/it]midi2opus: track #2 length 9582194 is too large
#   1%|█▍                                                                                                                        | 10699/939961 [1:28:25<580:33:12,  2.25s/it]midi2opus: midi starts with b'<!--' instead of 'MThd'
#   1%|█▍                                                                                                                        | 10703/939961 [1:28:33<517:21:58,  2.00s/it]midi2opus: track #12 length 1816005898 is too large
#   1%|█▍                                                                                                                         | 10724/939961 [1:28:51<73:18:46,  3.52it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   1%|█▍                                                                                                                        | 10778/939961 [1:29:11<110:54:26,  2.33it/s]midi2opus: midi starts with b'<htm' instead of 'MThd'
#   1%|█▍                                                                                                                        | 10828/939961 [1:29:28<108:00:47,  2.39it/s]midi2opus: track #18 length 2252222081 is too large
#   1%|█▍                                                                                                                         | 10896/939961 [1:29:51<58:29:48,  4.41it/s]midi2opus: track #20 length 2672716673 is too large
#   1%|█▍                                                                                                                         | 10898/939961 [1:29:52<80:30:31,  3.21it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   1%|█▍                                                                                                                         | 10901/939961 [1:29:52<53:36:58,  4.81it/s]midi2opus: track #5 length 18657 is too large
#   1%|█▍                                                                                                                         | 10937/939961 [1:30:03<70:21:16,  3.67it/s]midi2opus: track #20 length 16223101 is too large
#   1%|█▍                                                                                                                         | 10944/939961 [1:30:06<78:38:45,  3.28it/s]midi2opus: midi starts with b'RIFF' instead of 'MThd'
#   1%|█▍                                                                                                                         | 11048/939961 [1:30:43<63:33:47,  4.06it/s]midi2opus: track #5 length 303360 is too large
#   1%|█▍                                                                                                                        | 11069/939961 [1:30:51<156:31:19,  1.65it/s]midi2opus: track #6 length 437918234 is too large
#   1%|█▍                                                                                                                         | 11156/939961 [1:31:21<62:36:52,  4.12it/s]midi2opus: track #12 length 1330400256 is too large
#   1%|█▍                                                                                                                         | 11234/939961 [1:31:52<77:14:28,  3.34it/s]midi2opus: track #11 length 17771520 is too large
#   1%|█▍                                                                                                                        | 11296/939961 [1:32:17<104:35:23,  2.47it/s]midi2opus: track #4 length 8415 is too large
#   1%|█▍                                                                                                                         | 11342/939961 [1:32:30<94:42:13,  2.72it/s]midi2opus: track #9 length 4521984 is too large
#   1%|█▍                                                                                                                         | 11358/939961 [1:32:35<76:45:04,  3.36it/s]midi2opus: track #2 length 1090519442 is too large
#   1%|█▌                                                                                                                         | 11536/939961 [1:33:42<93:28:21,  2.76it/s]midi2opus: midi starts with b'\x00\x00\x00\x00' instead of 'MThd'
#   1%|█▌                                                                                                                         | 11555/939961 [1:33:48<74:40:57,  3.45it/s]midi2opus: track #14 length 1734829312 is too large
#   1%|█▌                                                                                                                         | 11620/939961 [1:34:06<70:06:52,  3.68it/s]midi2opus: track #2 length 2452766208 is too large
#   1%|█▌                                                                                                                        | 11701/939961 [1:34:34<112:23:16,  2.29it/s]midi2opus: track #2 length 708840339 is too large
#   1%|█▌                                                                                                                        | 11732/939961 [1:34:45<106:06:47,  2.43it/s]midi2opus: track #2 length 43139394 is too large
#   1%|█▌                                                                                                                         | 11749/939961 [1:34:48<60:32:36,  4.26it/s]midi2opus: track #1 length 46309 is too large
#   1%|█▌                                                                                                                         | 11766/939961 [1:34:52<90:45:29,  2.84it/s]midi2opus: track #7 length 437918234 is too large
#   1%|█▌                                                                                                                         | 11854/939961 [1:35:28<99:52:31,  2.58it/s]midi2opus: track #14 length 3027556 is too large
#   1%|█▌                                                                                                                         | 11956/939961 [1:36:03<50:35:44,  5.09it/s]midi2opus: track #2 length 2569666575 is too large
#   1%|█▌                                                                                                                        | 12005/939961 [1:36:18<117:10:42,  2.20it/s]midi2opus: track #12 length 1077646149 is too large
#   1%|█▌                                                                                                                         | 12079/939961 [1:36:42<64:42:00,  3.98it/s]set_sequence_number: length must be 2, not 0
#   1%|█▌                                                                                                                         | 12133/939961 [1:37:03<62:54:55,  4.10it/s]midi2opus: track #8 length 993001781 is too large
#   1%|█▌                                                                                                                         | 12372/939961 [1:38:36<54:26:43,  4.73it/s]midi2opus: midi starts with b'\x00/\x00\x00' instead of 'MThd'
#   1%|█▌                                                                                                                        | 12415/939961 [1:38:49<121:05:19,  2.13it/s]midi2opus: midi starts with b'\x00\rPr' instead of 'MThd'
#   1%|█▌                                                                                                                        | 12462/939961 [1:39:34<395:54:19,  1.54s/it]midi2opus: track #15 length 437918234 is too large
#   1%|█▌                                                                                                                        | 12505/939961 [1:40:55<351:52:17,  1.37s/it]midi2opus: track #18 length 84268038 is too large
#   1%|█▋                                                                                                                        | 12541/939961 [1:41:08<106:52:43,  2.41it/s]midi2opus: track #16 length 708116498 is too large
#   1%|█▋                                                                                                                        | 12545/939961 [1:41:10<102:10:47,  2.52it/s]midi2opus: track #2 length 8796480 is too large
#   1%|█▋                                                                                                                         | 12680/939961 [1:41:56<63:14:32,  4.07it/s]Running status not set; Aborting track.
#   1%|█▋                                                                                                                         | 12727/939961 [1:42:14<86:28:58,  2.98it/s]

# %% [markdown]
# # (Download and unzip training data)

# %%
# # Perceiver Solo Piano Training Data Pack
# %cd /data/ironman/data1/users/astais/Processed-Datasets/
# # !wget --no-check-certificate -O 'Perceiver-Piano-Training-Data.zip' "https://onedrive.live.com/download?cid=8A0D502FC99C608F&resid=8A0D502FC99C608F%2118740&authkey=ANEK-9WanNFyalw"
# !unzip 'Perceiver-Piano-Training-Data.zip'
# # !rm 'Perceiver-Piano-Training-Data.zip'
# %cd /home/astais/Perceiver-Music-Transformer/Training-Code/

# %% [markdown]
# # Load training data

# %%
# Load training data

# Pickle processed dataset files
#dataset_addr = '/data/data1/users/astais/Processed-Datasets/MusicTransformer-tensorflow2.0/classic-piano' #ironman
# dataset_name='GiantMIDI-Piano'
# dataset_addr='/data/ironman/data1/users/astais/Processed-Datasets/GiantMIDI-Piano'
#dataset_name='GiantMIDI-Piano'
# dataset_addr='/data/ironman/data1/users/astais/Processed-Datasets/MusicTransformer-tensorflow2.0/GiantMIDI-Piano'
# dataset_name='maestro-v3.0.0'
# dataset_addr='/data/ironman/data1/users/astais/Processed-Datasets/MusicTransformer-tensorflow2.0/maestro-v3.0.0'

filez = list()
for (dirpath, dirnames, filenames) in os.walk(dataset_addr):
    filez += [os.path.join(dirpath, file) for file in filenames]
print('=' * 70)

filez.sort()

print('Loading training data... Please wait...')

train_data = torch.Tensor()

for f in filez:
    train_data = torch.cat((train_data, torch.Tensor(pickle.load(open(f, 'rb')))))
    print('Loaded file:', f)
    
print('Done!')
# Out:
# ======================================================================
# Loading training data... Please wait...
# Loaded file: /data/ironman/data1/users/astais/Processed-Datasets/perceiver-ar/perceiver-ar_ailabs1k17/perceiver-ar_ailabs1k17.pickle
# Done!

# %%
len(train_data)
# Out:
# 9113840

# %%
train_data[:15], train_data[-15:]
# Out:
# (tensor([126., 254., 256., 384.,   0., 234., 322., 442.,  48., 217., 294., 424.,
#           60., 192., 330.]),
#  tensor([254., 318., 438.,   0., 254., 313., 440.,   0., 131., 306., 438.,   0.,
#          254., 294., 439.]))

# %% [markdown]
# # Initialize the Model

# %%
torch.cuda.empty_cache()
# Setup model

# constants

SEQ_LEN = 4096 * 4 # Total of 16k
PREFIX_SEQ_LEN = (4096 * 4) - 1024 # 15.3k

BATCH_SIZE = 1  #original 4
NUM_BATCHES = 20*len(train_data) // SEQ_LEN // BATCH_SIZE # change multiply ratio based on dataset dimension

GRADIENT_ACCUMULATE_EVERY = 4
LEARNING_RATE = 2e-5
VALIDATE_EVERY  = 100 
GENERATE_EVERY  = 200 
SAVE_EVERY = 500 #original 2000
GENERATE_LENGTH = 32 

# helpers

def cycle(loader):
    while True:
        for data in loader:
            yield data

# instantiate model

model = PerceiverAR(
    num_tokens = 512, # feizc 256
    dim = 1024, # feizc 512
    depth = 24, # original 24, feizc 8, last one 12
    heads = 16, # original 16, feizc 8, last one 12
    dim_head = 64,
    cross_attn_dropout = 0.5,
    max_seq_len = SEQ_LEN,
    cross_attn_seq_len = PREFIX_SEQ_LEN
)

model = AutoregressiveWrapper(model)
model.cuda()

print('Done!')
      
summary(model)

# prepare enwik8 data

class MusicDataset(Dataset):
    def __init__(self, data, seq_len):
        super().__init__()
        self.data = data
        self.seq_len = seq_len

    def __getitem__(self, index):
        
        # random sampling
        # idx = secrets.randbelow((self.data.size(0) // (self.seq_len))-1) * (self.seq_len)
        
        # consequtive sampling seems to be better at 64k seq_len
        idx = index * self.seq_len
        
        full_seq = self.data[idx: idx + self.seq_len + 1].long()
        return full_seq.cuda()

    def __len__(self):
        return (self.data.size(0) // self.seq_len)-1

train_dataset = MusicDataset(train_data, SEQ_LEN)
val_dataset   = MusicDataset(train_data, SEQ_LEN)
train_loader  = cycle(DataLoader(train_dataset, batch_size = BATCH_SIZE))
val_loader    = cycle(DataLoader(val_dataset, batch_size = BATCH_SIZE))

# optimizer

optim = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# Done!
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# ├─PerceiverAR: 1-1                                 --
# |    └─Embedding: 2-1                              524,288
# |    └─Embedding: 2-2                              16,777,216
# |    └─RotaryEmbedding: 2-3                        --
# |    └─ModuleList: 2-4                             --
# |    |    └─ModuleList: 3-1                        12,590,080
# |    └─ModuleList: 2-5                             --
# |    |    └─ModuleList: 3-2                        12,587,008
# |    |    └─ModuleList: 3-3                        12,587,008
# |    |    └─ModuleList: 3-4                        12,587,008
# |    |    └─ModuleList: 3-5                        12,587,008
# |    |    └─ModuleList: 3-6                        12,587,008
# |    |    └─ModuleList: 3-7                        12,587,008
# |    |    └─ModuleList: 3-8                        12,587,008
# |    |    └─ModuleList: 3-9                        12,587,008
# |    |    └─ModuleList: 3-10                       12,587,008
# |    |    └─ModuleList: 3-11                       12,587,008
# |    |    └─ModuleList: 3-12                       12,587,008
# |    |    └─ModuleList: 3-13                       12,587,008
# |    |    └─ModuleList: 3-14                       12,587,008
# |    |    └─ModuleList: 3-15                       12,587,008
# |    |    └─ModuleList: 3-16                       12,587,008
# |    |    └─ModuleList: 3-17                       12,587,008
# |    |    └─ModuleList: 3-18                       12,587,008
# |    |    └─ModuleList: 3-19                       12,587,008
# |    |    └─ModuleList: 3-20                       12,587,008
# |    |    └─ModuleList: 3-21                       12,587,008
# |    |    └─ModuleList: 3-22                       12,587,008
# |    |    └─ModuleList: 3-23                       12,587,008
# |    |    └─ModuleList: 3-24                       12,587,008
# |    |    └─ModuleList: 3-25                       12,587,008
# |    └─Linear: 2-6                                 524,288
# ===========================================================================
# Total params: 332,504,064
# Trainable params: 332,504,064
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# # TRAIN

# %%
# Train the model
train_losses = []
val_losses = []
train_accs = []
val_accs = []

# Variables for saving best evalaution loss,acc
best_val_acc        = 0.0
best_val_acc_step  = -1
best_val_loss       = float("inf")
best_val_loss_step = -1
# best_acc_file = '/data/data1/users/astais/Saved-Models/perceiver-ar/'+dataset_name+'_best-val-acc.pth'
# best_loss_file = '/data/data1/users/astais/Saved-Models/perceiver-ar/'+dataset_name+'_best-val-loss.pth'

# Training Loop
for i in tqdm(range(NUM_BATCHES), mininterval=10., desc='Training'):
    new_best = False
    model.train()

    for __ in range(GRADIENT_ACCUMULATE_EVERY):
        loss, acc = model(next(train_loader))
        loss.backward()

#     print(f'Training loss: {loss.item()}')
#     print(f'Training acc: {acc.item()}')
    
    train_losses.append(loss.item())
    train_accs.append(acc.item())
    
    torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
    optim.step()
    optim.zero_grad()
       
    if i % VALIDATE_EVERY == 0:
        model.eval()
        with torch.no_grad():
            val_loss, val_acc = model(next(val_loader))
#             print(f'Validation loss: {val_loss.item()}')
#             print(f'Validation acc: {val_acc.item()}')
            val_losses.append(val_loss.item())
            val_accs.append(val_acc.item())

  
    if i % GENERATE_EVERY == 0:
        model.eval()
        inp = random.choice(val_dataset)[:-1]
#         print(inp)
        sample = model.generate(inp[None, ...], GENERATE_LENGTH)
#         print(sample)
    
    # Save Model & Plot Graphs: Trained for necessery batches and new evaluation loss or accuracy best
    if i % VALIDATE_EVERY == 0 and i>NUM_BATCHES//40  and (val_acc > best_val_acc or val_loss < best_val_loss):
        
        print('Saving model progress. Please wait...')
        # Check if val_acc or val_loss are best so far
        if(val_acc > best_val_acc):
                best_val_acc = val_acc
                best_val_acc_step  = i
                best_acc_file = base_save_dir+'perceiver-ar_'+dataset_name+'_'+ str(i) + '_steps_' + str(round(float(val_accs[-1]), 4)) + '_acc.pth'
                torch.save(model.state_dict(), best_acc_file)

        if(val_loss < best_val_loss):
                best_val_loss       = val_loss
                best_val_loss_step = i
                best_loss_file = base_save_dir+'perceiver-ar_'+dataset_name+'_'+ str(i) + '_steps_' + str(round(float(val_losses[-1]), 4)) + '_loss.pth'
                torch.save(model.state_dict(), best_loss_file)

        print("Best val acc step:", best_val_acc_step)
        print("Best val acc:", best_val_acc)
        print("Best val loss step:", best_val_loss_step)
        print("Best val loss:", best_val_loss)
        print('Done!')
        
        # Plotting Training, Evaluation Graphs
        fig, ax = plt.subplots()
        ax.plot([i for i in range(len(train_losses))] ,train_losses, '#607B8B')
        ax.set(xlabel='Steps', ylabel ='Training Loss', title='Perceiver-AR '+dataset_name+': Training Loss')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train-loss_'+str(i) + '_steps.png')
#         plt.show()
        plt.close()

        # Training acc graph
        fig, ax = plt.subplots()
        ax.plot([i for i in range(len(train_accs))] ,train_accs, '#607B8B')
        ax.set(xlabel='Steps', ylabel ='Training Accuracy', title='Perceiver-AR '+dataset_name+': Training Accuracy')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train-acc_'+str(i) + '_steps.png')
#         plt.show()
        plt.close()

        # Validation loss graph
        fig, ax = plt.subplots()
        ax.plot([100*i for i in range(len(val_losses))] ,val_losses, '#5D478B')
        ax.set(xlabel='Steps', ylabel ='Validation Loss', title='Perceiver-AR '+dataset_name+': Validation Loss')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_val-loss_'+str(i) + '_steps.png')
#         plt.show()
        plt.close()

        # Validation acc graph
        fig, ax = plt.subplots()
        plt.plot([100*i for i in range(len(val_accs))] ,val_accs, '#5D478B')
        ax.set(xlabel='Steps', ylabel ='Validation Accuracy', title='Perceiver-AR '+dataset_name+': Validation Accuracy')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_val-acc_'+str(i) + '_steps.png')
#         plt.show()
        plt.close()

        # Training-Validation Loss Graph
        fig, ax = plt.subplots()
        x_train=np.array([i for i in range(len(train_losses))])
        y_train=np.array(train_losses)
        ax.plot(x_train,y_train, '#607B8B')
        # , marker='o',markevery = np.where(x_train%500==0, True, False))

        x_val=np.array([100*i for i in range(len(val_losses))])
        y_val=np.array(val_losses)
        ax.plot(x_val,y_val, '#5D478B')
        #         , marker='o',markevery = np.where(x_val%500==0, True, False))

        ax.set(xlabel='Steps', ylabel ='Loss', title='Perceiver-AR '+dataset_name+': Training-Validation Loss')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.legend(['Training Loss','Validation Loss'], loc='upper right')
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train,val-loss_'+str(i) + '_steps.png')
        plt.show()
        plt.close()

        # Training-Validation Accuracy Graph
        fig, ax = plt.subplots()
        x_train=np.array([i for i in range(len(train_accs))])
        y_train=np.array(train_accs)
        ax.plot(x_train,y_train, '#607B8B')
        #         , marker='o',markevery = np.where(x_train%500==0, True, False))

        x_val=np.array([100*i for i in range(len(val_accs))])
        y_val=np.array(val_accs)
        ax.plot(x_val,y_val, '#5D478B')
        #         ,marker='o', markevery = np.where(x_val%500==0, True, False))

        ax.set(xlabel='Steps', ylabel ='Accuracy', title='Perceiver-AR '+dataset_name+': Training-Validation Accuracy')
        ax.xaxis.set_minor_locator(AutoMinorLocator(5))
        ax.yaxis.set_minor_locator(AutoMinorLocator(5))
        ax.legend(['Training Accuracy','Validation Accuracy'], loc='lower right')
        ax.grid(which='minor', alpha=0.2)
        ax.grid(which='major', alpha=0.5)
        fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train,val-acc_'+str(i) + '_steps.png')
        plt.show()
        plt.close()
# Out:
# Training:   3%|███▏                                                                                                                   | 300/11125 [09:59<5:55:08,  1.97s/it]
# Saving model progress. Please wait...
# Training:   3%|███▏                                                                                                                   | 300/11125 [10:10<5:55:08,  1.97s/it]
# Best val acc step: 300
# Best val acc: tensor(0.1367, device='cuda:0')
# Best val loss step: 300
# Best val loss: tensor(3.1787, device='cuda:0')
# Done!
# Training:   6%|███████▍                                                                                                               | 697/11125 [27:07<5:44:45,  1.98s/it]
# Saving model progress. Please wait...
# Training:   6%|███████▍                                                                                                               | 697/11125 [27:20<5:44:45,  1.98s/it]
# Best val acc step: 700
# Best val acc: tensor(0.1924, device='cuda:0')
# Best val loss step: 700
# Best val loss: tensor(2.9773, device='cuda:0')
# Done!
# Training:   9%|██████████▋                                                                                                            | 998/11125 [41:10<5:32:01,  1.97s/it]
# Saving model progress. Please wait...
# Best val acc step: 700
# Best val acc: tensor(0.1924, device='cuda:0')
# Best val loss step: 1000
# Best val loss: tensor(2.9338, device='cuda:0')
# Done!
# Training:  11%|████████████▋                                                                                                         | 1198/11125 [49:37<5:28:58,  1.99s/it]
# Saving model progress. Please wait...
# Training:  11%|████████████▋                                                                                                         | 1198/11125 [49:50<5:28:58,  1.99s/it]
# Best val acc step: 1200
# Best val acc: tensor(0.2041, device='cuda:0')
# Best val loss step: 1000
# Best val loss: tensor(2.9338, device='cuda:0')
# Done!
# Training:  13%|██████████████▊                                                                                                       | 1395/11125 [58:30<5:20:12,  1.97s/it]
# Saving model progress. Please wait...
# Best val acc step: 1400
# Best val acc: tensor(0.2627, device='cuda:0')
# Best val loss step: 1400
# Best val loss: tensor(2.6321, device='cuda:0')
# Done!
# Training:  14%|████████████████▋                                                                                                   | 1596/11125 [1:09:00<5:12:50,  1.97s/it]
# Saving model progress. Please wait...
# Best val acc step: 1600
# Best val acc: tensor(0.2744, device='cuda:0')
# Best val loss step: 1600
# Best val loss: tensor(2.4759, device='cuda:0')
# Done!
# Training:  15%|█████████████████▋                                                                                                  | 1697/11125 [1:16:05<5:14:35,  2.00s/it]
# Saving model progress. Please wait...
# Training:  15%|█████████████████▋                                                                                                  | 1697/11125 [1:16:20<5:14:35,  2.00s/it]
# Best val acc step: 1700
# Best val acc: tensor(0.3594, device='cuda:0')
# Best val loss step: 1700
# Best val loss: tensor(2.3130, device='cuda:0')
# Done!
# Training:  18%|████████████████████▊                                                                                               | 1994/11125 [1:29:47<4:57:20,  1.95s/it]

# %% [markdown]
# # Save stats graphs and value arrays

# %%
# Save training, validation value arrays
with open(train_out_dir+'perceiver_ar'+dataset_name+current_time'.npy', 'wb') as f:
    np.save(f, np.array(train_losses))
    np.save(f, np.array(train_accs))
    np.save(f, np.array(val_losses))
    np.save(f, np.array(val_accs))

# Training loss graph
fig, ax = plt.subplots()
ax.plot([i for i in range(len(train_losses))] ,train_losses, '#607B8B')
ax.set(xlabel='Steps', ylabel ='Training Loss', title='Perceiver-AR '+dataset_name+': Training Loss')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train-loss.png')
plt.show()
plt.close()

# Training acc graph
fig, ax = plt.subplots()
ax.plot([i for i in range(len(train_accs))] ,train_accs, '#607B8B')
ax.set(xlabel='Steps', ylabel ='Training Accuracy', title='Perceiver-AR '+dataset_name+': Training Accuracy')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train-acc.png')
plt.show()
plt.close()

# Validation loss graph
fig, ax = plt.subplots()
ax.plot([100*i for i in range(len(val_losses))] ,val_losses, '#5D478B')
ax.set(xlabel='Steps', ylabel ='Validation Loss', title='Perceiver-AR '+dataset_name+': Validation Loss')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_val-loss.png')
plt.show()
plt.close()

# Validation acc graph
fig, ax = plt.subplots()
plt.plot([100*i for i in range(len(val_accs))] ,val_accs, '#5D478B')
ax.set(xlabel='Steps', ylabel ='Validation Accuracy', title='Perceiver-AR '+dataset_name+': Validation Accuracy')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_val-acc.png')
plt.show()
plt.close()

# Training-Validation Loss Graph
fig, ax = plt.subplots()
x_train=np.array([i for i in range(len(train_losses))])
y_train=np.array(train_losses)
ax.plot(x_train,y_train, '#607B8B')
# , marker='o',markevery = np.where(x_train%500==0, True, False))

x_val=np.array([100*i for i in range(len(val_losses))])
y_val=np.array(val_losses)
ax.plot(x_val,y_val, '#5D478B')
#         , marker='o',markevery = np.where(x_val%500==0, True, False))

ax.set(xlabel='Steps', ylabel ='Loss', title='Perceiver-AR '+dataset_name+': Training-Validation Loss')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.legend(['Training Loss','Validation Loss'], loc='upper right')
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train,val-loss.png')
plt.show()
plt.close()

# Training-Validation Accuracy Graph
fig, ax = plt.subplots()
x_train=np.array([i for i in range(len(train_accs))])
y_train=np.array(train_accs)
ax.plot(x_train,y_train, '#607B8B')
#         , marker='o',markevery = np.where(x_train%500==0, True, False))

x_val=np.array([100*i for i in range(len(val_accs))])
y_val=np.array(val_accs)
ax.plot(x_val,y_val, '#5D478B')
#         ,marker='o', markevery = np.where(x_val%500==0, True, False))

ax.set(xlabel='Steps', ylabel ='Accuracy', title='Perceiver-AR '+dataset_name+': Training-Validation Accuracy')
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))
ax.legend(['Training Accuracy','Validation Accuracy'], loc='lower right')
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
fig.savefig(train_out_dir+'perceiver-ar_'+dataset_name+'_train,val-acc.png')
plt.show()
plt.close()

# %% [markdown]
# # Load/Reload the Model

# %%
# Load model

# constants
SEQ_LEN = 4096 * 4 # Total of 16k
PREFIX_SEQ_LEN = (4096 * 4) - 1024 # 15.3k

model = PerceiverAR(
    num_tokens = 512,
    dim = 1024,
    depth = 24, #24,
    heads = 16, 
    dim_head = 64,
    cross_attn_dropout = 0.5,
    max_seq_len = SEQ_LEN,
    cross_attn_seq_len = PREFIX_SEQ_LEN
)
model = AutoregressiveWrapper(model)
model.cuda()

state_dict = torch.load(fname)

model.load_state_dict(state_dict)

model.eval()

# Model stats

summary(model)

# %%
# Plot Token Embeddings

cos_sim = metrics.pairwise.cosine_similarity(
    model.net.token_emb.weight.cpu().detach().numpy()[0].reshape(-1, 1)
)
plt.figure(figsize=(8, 8))
plt.imshow(cos_sim, cmap="inferno", interpolation="none")
im_ratio = cos_sim.shape[0] / cos_sim.shape[1]
plt.colorbar(fraction=0.046 * im_ratio, pad=0.04)
plt.xlabel("Position")
plt.ylabel("Position")
plt.tight_layout()
plt.plot()
plt.savefig(train_out_dir+"perceiver-ar_"+dataset_name+"_positional-embeddings.png", bbox_inches="tight")

# %% [markdown]
# # EVAL

# %%
# Custom MIDI option

print('Loading custom MIDI file...')

f = '/home/astais/Perceiver-Music-Transformer/Training-Code/tegridy-tools/tegridy-tools/seed2.mid'

score = TMIDIX.midi2ms_score(open(f, 'rb').read())

events_matrix = []

itrack = 1

while itrack < len(score):
    for event in score[itrack]:         
        if event[0] == 'note' and event[3] != 9:
            events_matrix.append(event)
    itrack += 1

if len(events_matrix) > 0:

    # Sorting...
    events_matrix.sort(key=lambda x: x[4], reverse=True)
    events_matrix.sort(key=lambda x: x[1])

    # recalculating timings
    for e in events_matrix:
        e[1] = int(e[1] / 10)
        e[2] = int(e[2] / 20)

    # final processing...
    inputs = []
    
    inputs.extend([126+0, 126+128, 0+256, 0+384]) # Intro/Zero sequence

    pe = events_matrix[0]
    for e in events_matrix:

        time = max(0, min(126, e[1]-pe[1]))
        dur = max(1, min(126, e[2]))

        ptc = max(1, min(126, e[4]))
        vel = max(1, min(126, e[5]))

        inputs.extend([time+0, dur+128, ptc+256, vel+384])

        pe = e
        
print('Done!')

# %%
# Generate

import time

model.eval()
inp = val_dataset[0]

print(inp)

start_time = time.time()

out = model.generate(inp[None, ...], 
                     128, 
                     temperature=0.6)

print(time.time() - start_time, "seconds")
print(out)

out1 = out.cpu().tolist()[0]

# %%
# Convert to MIDI
if len(out1) != 0:
    
    song = out1
    song_f = []
    time = 0
    dur = 0
    vel = 0
    pitch = 0
    channel = 0

    son = []

    song1 = []

    for s in song:
      if s > 127:
        son.append(s)

      else:
        if len(son) == 4:
          song1.append(son)
        son = []
        son.append(s)
    
    for s in song1:

        channel = 0 # Piano

        time += s[0] * 10
            
        dur = (s[1]-128) * 20
        
        pitch = (s[2]-256)

        vel = (s[3]-384)
                                  
        song_f.append(['note', time, dur, channel, pitch, vel ])

    detailed_stats = TMIDIX.Tegridy_SONG_to_MIDI_Converter(song_f,
                                                        output_signature = 'Perceiver',  
                                                        output_file_name = '/data/ironman/data1/users/astais/Midi-Outputs/perceiver-ar/perceiver-ar_'+dataset_name+'_'+current_time, 
                                                        track_name='Project Los Angeles',
                                                        list_of_MIDI_patches=[0, 24, 32, 40, 42, 46, 56, 71, 73, 0, 53, 19, 0, 0, 0, 0],
                                                        number_of_ticks_per_quarter=500)

    print('Done!')
