# %%
Mus Eval Help

# %%
# Probability
# weights = np.ones_like(mus_metr_t[1])/len(mus_metr_t[1])
# Histogram of pitch range
# plt.hist(mus_metr_t[1],30,weights=weights, facecolor='b', alpha=0.75)
# plt.hist(mus_metr_t[1],24,weights=weights, density=True, facecolor='b', alpha=0.75)
# pd.DataFrame(mus_metr_t[1]).plot(kind='density')
# plt.xlabel('Pitch Range')
# plt.ylabel('Probability')
# plt.title("Pitch Range Probability: "+dataset)

# sns.set_style('whitegrid')
# sns.kdeplot(mus_metr_t[1], bw=0.5)
# sns.distplot(mus_metr_t[1], hist=True, kde=True, 
#              bins=24,color = 'darkblue', 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 2})

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    plt.text(0.05, 0.95,r'$\mu='+str(mu)+',\ \sigma=$'+str(sigma),transform=ax.transAxes,verticalalignment='top', bbox=props)
#     , textstr, transform=ax.transAxes, fontsize=14,
        
    # sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# Count number of midis in directory
# if you don't want to recursively search in the subdirectory
# mid_num=len([f for f in os.listdir(directory) 
#      if f.endswith('.mid') and os.path.isfile(os.path.join(directory, f))])

# for filename in tqdm(os.listdir(directory)):
#     f = os.path.join(directory, filename)
    
#     # For every midi file
#     if os.path.isfile(f) and f.endswith('.mid'):

# for subdir, dirs, files in os.walk(directory):
#     for file in files:
#         #print os.path.join(subdir, file)
#         filepath = subdir + os.sep + file

#         if filepath.endswith(".mid"):
#             print (filepath)

# path = directory+'**/*.mid'
# files = glob.glob(path, recursive=True)
# print(files)

# for path in Path(directory).rglob('*.mid'):
#     print(path)

# %%
# !gpustat

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
from numpy import random
import matplotlib.colors as mcolors

fig, ax = plt.subplots()
b=np.array(random.exponential(scale=0.01, size=(10000)))
a=np.array([i for i in range(len(b))])
d=np.array(random.rand(100))
c=np.array([100*i for i in range(len(d))])
print(c)
print(d)

ax.plot(a,b, '-o',color='#EE799F',markerfacecolor='#8B0A50',markevery = np.where(a%1000==0, True, False))
ax.plot(c,d, '-go',markevery = np.where(c%500==0, True, False))
ax.set(xlabel='Steps 2', ylabel='Validation Loss',
       title='Validation Loss')
# ax.grid(which='both')
# fig.savefig

ax.legend(['Kernel Density Estimation','Histogram Bars'], loc='upper right')

ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

# And a corresponding grid
# ax.grid(which='both')

# # Or if you want different settings for the grids:
ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

plt.show()
plt.close()
print('Done!')

# t = np.linspace(0,3,14)
# y = np.random.rand(len(t))

# plt.plot(t,y,'-gD',markevery = np.where(y > 0.5, True, False))
# or 
#plt.plot(t,y,'-gD',markevery = np.arange(len(t))[y > 0.5])

# plt.xlabel('t (s)')
# plt.ylabel('y')

# plt.show()

# for axs, markevery in zip(ax.flat, cases):
#     axs.set_title(f'markevery={markevery}')
#     ax.plot(x, y, 'o', ls='-', ms=4, markevery=markevery)
# Out:
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100
#  4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500
#  5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900
#  7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300
#  8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700
#  9800 9900]
# [0.81289634 0.74597194 0.26031216 0.67699718 0.80080404 0.91934114
#  0.90129385 0.3015441  0.37958932 0.12297241 0.73662528 0.67143871
#  0.10399439 0.62315137 0.45079282 0.68429323 0.07794206 0.33143014
#  0.32882622 0.01262096 0.08046229 0.27622293 0.64060873 0.4728828
#  0.61406089 0.63841372 0.59997367 0.68922051 0.08187102 0.71811723
#  0.09205839 0.45951971 0.89726426 0.55119787 0.07094281 0.22165748
# ...

# %%
        plt.legend(['Kernel Density Estimation','Histogram Bars'], loc='upper center', bbox_to_anchor=(0.5, -0.5),
          fancybox=True, shadow=True, ncol=2)

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
x = np.linspace(-2, 2, 10)
y = np.exp(x)
plt.plot(x, y)
plt.xlabel("e^x")
spacing = 0.100
fig.subplots_adjust(bottom=spacing)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# input=np.random.poisson(10,(20,3))
# print(input)
# df = pd.DataFrame(input,
#                   columns=['Knn', 'Kss', 'Ktt'])
# print(df)

# # Melt the results to create a single dataframe
# df_CohBeh = pd.melt(df, value_vars=['Knn', 'Kss', 'Ktt'], var_name='melt')

# sns.displot(data=df_CohBeh, hue='melt',x='value',
#             kind="kde", fill=True, legend=False, height=5, aspect=1.6, 
#             cut=0, bw_adjust=1)

num_rows = 20
years = list(range(1990, 1990 + num_rows))
data_preproc = pd.DataFrame({
    'Year': years, 
    'A': np.random.randn(num_rows).cumsum(),
    'B': np.random.randn(num_rows).cumsum(),
    'C': np.random.randn(num_rows).cumsum(),
    'D': np.random.randn(num_rows).cumsum()})
print(data_preproc)
sns.lineplot(x='Year', y='value', hue='variable', 
             data=pd.melt(data_preproc, ['Year']))
# Out:
#     Year         A         B         C         D
# 0   1990 -0.289881  0.032980  2.524328 -0.723232
# 1   1991 -1.647701  1.298137  1.497402 -0.764269
# 2   1992 -2.042267  1.645883  0.598678 -0.231087
# 3   1993 -3.602833  2.646153  0.318523  0.191898
# 4   1994 -4.959817  0.466376  0.041949 -0.653174
# 5   1995 -2.710800  1.067405 -0.724965 -2.459331
# 6   1996 -3.703803  2.089929 -0.805750 -2.451792
# 7   1997 -4.176218  2.075920 -2.691499 -2.579978
# 8   1998 -1.170905  2.471199 -2.707805 -4.357539
# 9   1999 -2.246111  2.314666 -1.751257 -3.815836
# 10  2000 -2.571045  0.339029 -1.234525 -3.958653
# 11  2001 -3.871191 -1.331344 -1.097899 -4.372661
# 12  2002 -5.342565 -3.142460 -0.484442 -3.347093
# 13  2003 -6.163583 -3.043772 -0.006714 -3.717017
# 14  2004 -5.340480 -2.721857  1.372524 -2.884443
# 15  2005 -5.679572 -4.152708  1.632553 -3.063335
# 16  2006 -5.300453 -4.092215  1.442729 -3.755938
# 17  2007 -6.048435 -5.416667  2.706588 -3.645988
# ...
